# %%
import pandas as pd
df = pd.read_parquet("sightings.parquet")

# %%
print(df["species"].value_counts())
# Out:
# species
# Phascolarctos cinereus      95576
# Macropus giganteus          62255
# Trichosurus vulpecula       61783
# Pseudocheirus peregrinus    56668
# Tachyglossus aculeatus      40440
# Wallabia bicolor            37032
# Vombatus ursinus            24798
# Notamacropus rufogriseus    18828
# Ornithorhynchus anatinus     9317
# Isoodon obesulus             3585
# Osphranter rufus             3369
# Name: count, dtype: int64
