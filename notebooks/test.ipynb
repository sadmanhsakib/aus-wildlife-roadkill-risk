# %%
import pandas as pd
import os

df = pd.read_parquet(os.path.join("..", "sightings.parquet"))

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 413651 entries, 0 to 413650
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   species             413651 non-null  str
#  1   month               413651 non-null  float64
#  2   year                413651 non-null  float64
#  3   latitude            413651 non-null  float64
#  4   longitude           413651 non-null  float64
#  5   season              413651 non-null  str
#  6   body_mass_weight    413651 non-null  float64
#  7   nocturnal_weight    413651 non-null  float64
#  8   peak_season_weight  413651 non-null  float64
#  9   geometry            413651 non-null  object
#  10  state               413651 non-null  str
#  11  road_segment_id     413651 non-null  str
#  12  road_class          413651 non-null  str
#  13  speed_limit         413651 non-null  int64
#  14  traffic_proxy       413651 non-null  int64
# ...
