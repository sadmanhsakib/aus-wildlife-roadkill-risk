# %%
import pandas as pd
import geopandas as gpd
import os

gdf = gpd.read_parquet(os.path.join("..", "road_segment_labels.parquet"))

gdf.info()

# %%
import pandas as pd
import geopandas as gpd
import os

gdf = gpd.read_parquet(os.path.join("..", "data/road_segments_scored.parquet"))
shap_df = pd.read_parquet(os.path.join("..", "data/shap_values.parquet"))

# %%
gdf[["predicted_risk", "proxy_risk"]]
# Out:
#        predicted_risk  proxy_risk
# 0            0.059519    0.019050
# 1            0.267417    0.495995
# 2            0.438213    0.465314
# 3            0.546793    0.539618
# 4            0.095781    0.239645
# ...               ...         ...
# 99734        0.197155    0.153701
# 99735        0.448017    0.594331
# 99736        0.809211    0.808370
# 99737        0.246976    0.364562
# 99738        0.271394    0.143605
#
# [99739 rows x 2 columns]
