# %%
import pandas as pd
import geopandas as gpd
import os

gdf = gpd.read_parquet(os.path.join("..", "data/road_segments_scored.parquet"))

gdf.info()

# %%
import pandas as pd
import geopandas as gpd
import os

shap_df = pd.read_parquet(os.path.join("..", "data/shap_values.parquet"))

# %%
import geopandas as gpd
import os

df = gpd.read_parquet(os.path.join("..", "sightings.parquet"))
df["year"].value_counts()
# Out:
# year
# 2021.0    78606
# 2023.0    75077
# 2024.0    74481
# 2022.0    65133
# 2025.0    55943
# 2020.0    53550
# 2026.0    10861
# Name: count, dtype: int64
