# %%
import pandas as pd
import geopandas as gpd
import os

gdf = gpd.read_parquet(os.path.join("..", "sightings/echidna.parquet"))

gdf

# %%
import pandas as pd
import geopandas as gpd
import os

shap_df = pd.read_parquet(os.path.join("..", "road_segments.parquet"))
shap_df.columns
