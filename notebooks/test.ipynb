# %%
import pandas as pd
import geopandas as gpd
import os

gdf = gpd.read_parquet(os.path.join("..", "road_segment_labels.parquet"))

# %%
print(gdf["geometry"].head())
# Out:
# 0    LINESTRING (1030310.352 5964865.081, 1030426.5...
# 1    LINESTRING (1442368.51 6220403.825, 1442401.14...
# 2    LINESTRING (1442587.844 6220225.882, 1442349.3...
# 3    LINESTRING (1688722.751 6886419.28, 1688681.25...
# 4    LINESTRING (1233941.653 6085408.16, 1233963.46...
# Name: geometry, dtype: geometry
