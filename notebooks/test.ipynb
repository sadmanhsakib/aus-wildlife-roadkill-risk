# %%
import pandas as pd
import os

df = pd.read_parquet(os.path.join("..", "sightings.parquet"))
df = pd.read_parquet(os.path.join("..", "road_segment_labels.parquet"))

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99739 entries, 0 to 99738
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   road_segment_id          99739 non-null  str
#  1   state                    99739 non-null  str
#  2   sighting_count           99739 non-null  int64
#  3   species_richness         99739 non-null  int64
#  4   mean_body_mass_weight    99739 non-null  float64
#  5   mean_nocturnal_weight    99739 non-null  float64
#  6   mean_peak_season_weight  99739 non-null  float64
#  7   mean_ndvi                99739 non-null  float64
#  8   road_class               99739 non-null  str
#  9   speed_limit              99739 non-null  int64
#  10  traffic_proxy            99739 non-null  int64
#  11  distance_to_road         99739 non-null  float64
#  12  geometry                 99739 non-null  object
#  13  proxy_risk               99739 non-null  float64
# ...
