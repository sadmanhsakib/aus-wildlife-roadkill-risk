# %%
import pandas as pd
df = pd.read_parquet("sightings.parquet")

# %%
print(df["state"].value_counts())
# Out:
# state
# NSW    265173
# VIC     65138
# QLD     49793
# SA      16547
# TAS      9201
# ACT      5250
# WA       1828
# NT        721
# Name: count, dtype: int64
