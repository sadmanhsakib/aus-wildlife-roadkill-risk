# %%
import pandas as pd
import geopandas as gpd
import os

gdf = gpd.read_parquet(os.path.join("..", "data/model/road_segments_scored.parquet"))
gdf = gdf[gdf["predicted_risk"] > 0.98]
print(gdf.shape)

# %%
import pandas as pd
import geopandas as gpd
import os

shap_df = gpd.read_parquet(os.path.join("..", "data/model/shap_values.parquet"))
shap_df.info()
