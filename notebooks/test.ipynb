# %%
import pandas as pd
import geopandas as gpd
import os

gdf = gpd.read_parquet(os.path.join("..", "data/model/road_segments_scored.parquet"))
drop_cols = [
        "road_segment_id",
        "state",
        "geometry",
        "ecological_score",
        "road_exposure_score",
        "raw_risk",
        "road_class",
        "spatial_lag",
        "blended_risk",
        "proxy_risk",
]

f = gdf.drop(columns=drop_cols).columns
f
# Out:
# Index(['sighting_count', 'species_richness', 'mean_body_mass_weight',
#        'mean_nocturnal_weight', 'mean_peak_season_weight',
#        'mean_distance_to_road', 'mean_ndvi', 'speed_limit', 'traffic_proxy',
#        'proximity', 'lag_sighting_count', 'lag_species_richness',
#        'lag_mean_ndvi', 'lag_traffic_proxy', 'predicted_risk'],
#       dtype='object')

# %%
import pandas as pd
import geopandas as gpd
import os

shap_df = pd.read_parquet(os.path.join("..", "data/model/shap_values.parquet"))
